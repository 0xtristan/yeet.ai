# %%
import googlemaps
from datetime import datetime
import json
import pandas as pd

# %%
gmaps = googlemaps.Client(key='AIzaSyDAOpH3KzlnMy45taoxIKMvDj23q4uneTI')

# # Geocoding an address
# geocode_result = gmaps.geocode('1600 Amphitheatre Parkway, Mountain View, CA')
#
# # Look up an address with reverse geocoding
# reverse_geocode_result = gmaps.reverse_geocode((40.714224, -73.961452))

# Request directions via public transit
now = datetime.now()
places_result = gmaps.places('places to eat near me',
                             location=(-33.865586,151.205439),
                             radius=400,
                             #open_now=True
                             )
#print(json.dumps(places_result,indent=4))
results = places_result['results']
place_data = [
    {
        'formatted_address':p['formatted_address'],
        'name':p['name'],
        'place_id':p['place_id'],
        'rating':p['rating'],
        'types':p['types']
    } for p in results]

#print(place_data)

# %%
df_place = pd.DataFrame(place_data)
df_place
# Out:
#                                     formatted_address  \
# 0         19-29 Martin Pl, Sydney NSW 2000, Australia
# 1       38 Campbell St, Haymarket NSW 2000, Australia
# 2    730-742 George St, Haymarket NSW 2000, Australia
# 3              37 York Ln, Sydney NSW 2000, Australia
# 4            15 Hunter St, Sydney NSW 2000, Australia
# 5   Corner of Pitt Street &, Angel Pl, Sydney NSW ...
# 6           1/222 Kent St, Sydney NSW 2000, Australia
# 7   Cnr Alfred Street &, Loftus St, Sydney NSW 200...
# 8       375-377 George St, Sydney NSW 2000, Australia
# 9   MLC Centre, 19 Martin Pl, Sydney NSW 2000, Aus...
# 10             2 Angel Pl, Sydney NSW 2000, Australia
# 11            105 Pitt St, Sydney NSW 2000, Australia
# 12       60 Carrington St, Sydney NSW 2000, Australia
# 13  Shop 28, MLC Center 19-29 Martin Place, Sydney...
# 14            1 Martin Pl, Sydney NSW 2000, Australia
# 15  MLC Centre, 6.23/19 Martin Pl, Sydney NSW 2000...
# 16             39 Lime St, Sydney NSW 2000, Australia
# 17              Alfred St, Sydney NSW 2000, Australia
# 18         1/49 Market St, Sydney NSW 2000, Australia
# 19    30 Lime St, Darling Harbour NSW 2000, Australia
#
#                             name                     place_id  rating  \
# 0                         Bun Me  ChIJz33wX4uxEmsROZhQ14ZttSs     3.7
# 1                       Chonsiam  ChIJ_zVB2yKuEmsReSR2Pc36qHg     4.0
# 2                       @Bangkok  ChIJ2a-5aSOuEmsRK1cpM8iuCoA     3.9
# 3       Made In Italy Sydney CBD  ChIJU1_axkCuEmsR5i01W5z69nI     4.2
# 4         Little Vietnamese Food  ChIJVTO0_0CuEmsRDKg49hustlw     3.0
# 5               Long Chim Sydney  ChIJ98SIQkCuEmsRQAStwDCAshw     3.9
# 6                     Pavel & Co  ChIJ83wVy0CuEmsRJcEl9Eid0ak     4.1
# 7      McDonald's Sydney Gateway  ChIJVaUz1GmuEmsRbP5RNeRV6no     3.6
# 8   McDonald's The Strand Arcade  ChIJ2fYBWjyuEmsRfDHULH_SDlY     3.7
# 9                 Burger Project  ChIJczKDGUCuEmsRGRRns-1GyZA     3.9
# 10                    China Lane  ChIJrXt7Z0CuEmsRyFe3eblxnVA     4.2
# 11                        Mejico  ChIJ34xIS0CuEmsRnEMEuiC7WcQ     4.1
# 12             Steel Bar & Grill  ChIJMfom7UCuEmsRf9iEhx7kZ-Y     4.1
# 13                        Thr1ve  ChIJSauXGUCuEmsR7f3rEyndSTA     3.5
# 14                     GPO Grand  ChIJW9L-1WeuEmsRecvA53RRSos     4.1
# 15                       Schnitz  ChIJnehJEECuEmsRQBfrBfxk7Z8     3.4
# 16                    The Malaya  ChIJ4U8HhjiuEmsRyevJVTxWbFo     4.3
# 17                Gateway Sydney  ChIJ_9AgbkKuEmsRAgAuY-sp7-s     4.2
# 18           Gowings Bar & Grill  ChIJlbpwVT6uEmsRFnaMgWJJ2Y0     4.2
# 19      Lal Qila Darling Harbour  ChIJ2Uvo-jquEmsRNhEao96WMwk     4.0
#
#                                                 types
# 0   [restaurant, food, point_of_interest, establis...
# 1   [restaurant, food, point_of_interest, establis...
# 2   [restaurant, food, point_of_interest, establis...
# 3   [restaurant, food, point_of_interest, establis...
# 4   [restaurant, food, point_of_interest, establis...
# 5   [bar, restaurant, food, point_of_interest, est...
# 6   [restaurant, food, point_of_interest, establis...
# 7   [meal_takeaway, restaurant, food, point_of_int...
# 8   [meal_takeaway, restaurant, food, point_of_int...
# 9   [restaurant, food, point_of_interest, establis...
# 10  [restaurant, food, point_of_interest, establis...
# 11  [bar, restaurant, food, point_of_interest, est...
# 12  [bar, restaurant, food, point_of_interest, est...
# 13  [store, health, restaurant, food, point_of_int...
# 14  [restaurant, cafe, night_club, bar, store, foo...
# 15  [restaurant, food, point_of_interest, establis...
# 16  [restaurant, food, point_of_interest, establis...
# 17  [cafe, meal_takeaway, restaurant, food, point_...
# 18  [restaurant, food, point_of_interest, establis...
# 19  [restaurant, food, point_of_interest, establis...

# %%
from instagram.client import InstagramAPI

access_token = "YOUR_ACCESS_TOKEN"
client_secret = "YOUR_CLIENT_SECRET"
api = InstagramAPI(access_token=access_token, client_secret=client_secret)
recent_media, next_ = api.user_recent_media(user_id="userid", count=10)
for media in recent_media:
   print media.caption.text

# %%
api.location_recent_media(count, max_id, location_id)*
